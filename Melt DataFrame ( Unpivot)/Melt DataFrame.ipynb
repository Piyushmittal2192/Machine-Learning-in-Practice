# %%
import pandas as pd

# %%
df = pd.read_excel("What is America's most popular sport.xlsx", sheet_name='Sheet1')

# %%
df
# Out:
#    Sport  Football  Basketball  Baseball  Soccer  Ice hockey  Auto racing  \
# 0   2017        37          11         9       7           4            2
# 1   2013        39          12        14       4           3            2
# 2   2008        41           9        10       3           4            3
# 3   2007        43          11        13       2           4            3
# 4   2006        43          12        11       2           2            4
# 5   2005        34          12        12       3           4            5
# 6   2004        37          13        10       2           3            5
#
#    Tennis  Golf  Volleyball  ...  Ice/Figure skating  Rodeo  Track and field  \
# 0       2     1           1  ...                   1      0                0
# 1       3     2           0  ...                   1      0                1
# 2       1     2           1  ...                   1      0                0
# ...

# %%
df.pivot()
